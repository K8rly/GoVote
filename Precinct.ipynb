# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
# 1. Create a DataFrame for the voting data. 
file_to_open = "rvht.csv"
vote_df = pd.read_csv(file_to_open, encoding="ISO-8859-1")
# Out:
# /Users/sarahdivakarla/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (13,25,26,28,35,39,41,42,44,56,71,77,78,82,84,88,89,91,97) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
vote_df.head()
# Out:
#    voter_id_org      STATE_ID          city  ward pct name_last name_first  \
# 0       2410948  OH0020345885  GARFIELD HTS     4   B   TEKAVEC       RYAN
# 1        189273  OH0014544976     CLEVELAND     9   H     GREEN        RAY
# 2        504938  OH0014696549  INDEPENDENCE     0   E    NELSON      CHRIS
# 3       2078785  OH0015598952  INDEPENDENCE     0   E    BECKER    ANTHONY
# 4       2773489  OH0024074123   VALLEY VIEW     0   A     ADAMS     TRAVIS
#
#   name_middle name_suffix Status  ... S_02_06_2007 S_08_08_2006 P_05_02_2006  \
# 0           M         NaN      A  ...          NaN          NaN          NaN
# 1     CLINTON         NaN      A  ...          NaN          NaN            D
# 2           F         NaN      A  ...          NaN          NaN          NaN
# 3           E         NaN      A  ...          NaN          NaN          NaN
# 4     MICHAEL         NaN      I  ...          NaN          NaN          NaN
#
# ...

# %%
vote_df['Precint'] = vote_df.agg(lambda x: f"{x['city']}-0{x['ward']}-{x['pct']}", axis=1)
vote_df
# Out:
#         voter_id_org      STATE_ID           city  ward pct name_last  \
# 0            2410948  OH0020345885   GARFIELD HTS     4   B   TEKAVEC
# 1             189273  OH0014544976      CLEVELAND     9   H     GREEN
# 2             504938  OH0014696549   INDEPENDENCE     0   E    NELSON
# 3            2078785  OH0015598952   INDEPENDENCE     0   E    BECKER
# 4            2773489  OH0024074123    VALLEY VIEW     0   A     ADAMS
# ...              ...           ...            ...   ...  ..       ...
# 873946       2623942  OH0022626849      PARMA HTS     1   C     WILLE
# 873947       1638210  OH0015036972  NORTH OLMSTED     4   E     TABOR
# 873948       2206148  OH0018801292  NORTH OLMSTED     4   E   GREGORY
# 873949       2980747  OH0026014666      CLEVELAND     7   W      ROSS
# 873950       3017222  OH0026414326    SEVEN HILLS     3   A    HOCUTT
#
#        name_first name_middle name_suffix Status  ... S_08_08_2006  \
# ...

# %%
vote_df['Precint'].unique()
# Out:
# array(['GARFIELD HTS-04-B', 'CLEVELAND-09-H', 'INDEPENDENCE-00-E',
#        'VALLEY VIEW-00-A', 'BROADVIEW HTS-03-D', 'INDEPENDENCE-00-C',
#        'INDEPENDENCE-00-A', 'INDEPENDENCE-00-D', 'SOLON-01-B',
#        'SOLON-07-B', 'SOLON-03-A', 'BEDFORD HTS-03-B',
#        'RICHMOND HTS-04-A', 'CLEVELAND-011-P', 'EUCLID-04-B',
#        'CLEVELAND-014-E', 'INDEPENDENCE-00-B', 'SEVEN HILLS-03-A',
#        'PARMA-07-A', 'CLEVELAND-02-D', 'CLEVELAND-08-K', 'SOLON-06-A',
#        'PARMA-04-D', 'PARMA-07-E', 'GARFIELD HTS-06-C', 'CLEVELAND-01-G',
#        'CLEVELAND-05-I', 'BRECKSVILLE-00-D', 'GARFIELD HTS-06-A',
#        'BROADVIEW HTS-02-A', 'SOLON-04-C', 'SOLON-03-B', 'SOLON-01-A',
#        'GARFIELD HTS-07-C', 'CLEVELAND-01-H', 'PEPPER PIKE-00-B',
#        'SOLON-05-A', 'SOUTH EUCLID-01-D', 'PEPPER PIKE-00-E',
#        'CLEVELAND-09-J', 'STRONGSVILLE-03-E', 'SOLON-06-B',
#        'BEDFORD HTS-02-A', 'EUCLID-02-A', 'CLEVELAND-01-J',
# ...

# %%
pctvote_df = vote_df.Precint.str.replace(r'^CLEVELAND-01', r'^CLEVELAND-1')
pctvote_df.unique()
# Out:
# /Users/sarahdivakarla/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# array(['GARFIELD HTS-04-B', 'CLEVELAND-09-H', 'INDEPENDENCE-00-E',
#        'VALLEY VIEW-00-A', 'BROADVIEW HTS-03-D', 'INDEPENDENCE-00-C',
#        'INDEPENDENCE-00-A', 'INDEPENDENCE-00-D', 'SOLON-01-B',
#        'SOLON-07-B', 'SOLON-03-A', 'BEDFORD HTS-03-B',
#        'RICHMOND HTS-04-A', '^CLEVELAND-11-P', 'EUCLID-04-B',
#        '^CLEVELAND-14-E', 'INDEPENDENCE-00-B', 'SEVEN HILLS-03-A',
#        'PARMA-07-A', 'CLEVELAND-02-D', 'CLEVELAND-08-K', 'SOLON-06-A',
#        'PARMA-04-D', 'PARMA-07-E', 'GARFIELD HTS-06-C', '^CLEVELAND-1-G',
#        'CLEVELAND-05-I', 'BRECKSVILLE-00-D', 'GARFIELD HTS-06-A',
#        'BROADVIEW HTS-02-A', 'SOLON-04-C', 'SOLON-03-B', 'SOLON-01-A',
# ...

# %%
vote_df.Precint.str.replace(r'^CLEVELAND-01', r'^CLEVELAND-1')
# Out:
# /Users/sarahdivakarla/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# 0          GARFIELD HTS-04-B
# 1             CLEVELAND-09-H
# 2          INDEPENDENCE-00-E
# 3          INDEPENDENCE-00-E
# 4           VALLEY VIEW-00-A
#                  ...
# 873946        PARMA HTS-01-C
# 873947    NORTH OLMSTED-04-E
# 873948    NORTH OLMSTED-04-E
# 873949        CLEVELAND-07-W
# 873950      SEVEN HILLS-03-A
# Name: Precint, Length: 873951, dtype: object

# %%
vote_df.head(15)
# Out:
#     voter_id_org      STATE_ID           city  ward pct           name_last  \
# 0        2410948  OH0020345885   GARFIELD HTS     4   B             TEKAVEC
# 1         189273  OH0014544976      CLEVELAND     9   H               GREEN
# 2         504938  OH0014696549   INDEPENDENCE     0   E              NELSON
# 3        2078785  OH0015598952   INDEPENDENCE     0   E              BECKER
# 4        2773489  OH0024074123    VALLEY VIEW     0   A               ADAMS
# 5        2407254  OH0020315612  BROADVIEW HTS     3   D             DELFELD
# 6        2773825  OH0024075952   INDEPENDENCE     0   C           POTAPCHUK
# 7        2078835  OH0015598245   INDEPENDENCE     0   A  LIEDERBACH BARTHER
# 8        2074927  OH0015588121   INDEPENDENCE     0   D          RADUJKOVIC
# 9        2412334  OH0020341713          SOLON     1   B             HEGEDUS
# 10       2131516  OH0015914041          SOLON     7   B             BARTELS
# ...

# %%
# vote_df["Precint"] = vote_df["Precint"].apply(lambda x: x.replace("CLEVELAND-011", "CLEVELAND-11"))
vote_df["Precint"] = vote_df["Precint"].apply(lambda x: x.replace("CLEVELAND-012", "CLEVELAND-12"))
vote_df["Precint"] = vote_df["Precint"].apply(lambda x: x.replace("CLEVELAND-013", "CLEVELAND-13"))
vote_df["Precint"] = vote_df["Precint"].apply(lambda x: x.replace("CLEVELAND-014", "CLEVELAND-14"))
vote_df["Precint"] = vote_df["Precint"].apply(lambda x: x.replace("CLEVELAND-015", "CLEVELAND-15"))
vote_df["Precint"] = vote_df["Precint"].apply(lambda x: x.replace("CLEVELAND-016", "CLEVELAND-16"))
vote_df["Precint"] = vote_df["Precint"].apply(lambda x: x.replace("CLEVELAND-017", "CLEVELAND-17"))
vote_df["Precint"] = vote_df["Precint"].apply(lambda x: x.replace("CLEVELAND-018", "CLEVELAND-18"))
vote_df["Precint"] = vote_df["Precint"].apply(lambda x: x.replace("CLEVELAND-019", "CLEVELAND-19"))
vote_df["Precint"].head(15)
# Out:
# 0      GARFIELD HTS-04-B
# 1         CLEVELAND-09-H
# 2      INDEPENDENCE-00-E
# 3      INDEPENDENCE-00-E
# 4       VALLEY VIEW-00-A
# 5     BROADVIEW HTS-03-D
# 6      INDEPENDENCE-00-C
# 7      INDEPENDENCE-00-A
# 8      INDEPENDENCE-00-D
# 9             SOLON-01-B
# 10            SOLON-07-B
# 11            SOLON-03-A
# 12      BEDFORD HTS-03-B
# 13     RICHMOND HTS-04-A
# 14        CLEVELAND-11-P
# Name: Precint, dtype: object

# %%
vote_df.head()
# Out:
#    voter_id_org      STATE_ID          city  ward pct name_last name_first  \
# 0       2410948  OH0020345885  GARFIELD HTS     4   B   TEKAVEC       RYAN
# 1        189273  OH0014544976     CLEVELAND     9   H     GREEN        RAY
# 2        504938  OH0014696549  INDEPENDENCE     0   E    NELSON      CHRIS
# 3       2078785  OH0015598952  INDEPENDENCE     0   E    BECKER    ANTHONY
# 4       2773489  OH0024074123   VALLEY VIEW     0   A     ADAMS     TRAVIS
#
#   name_middle name_suffix Status  ... S_08_08_2006 P_05_02_2006 S_02_07_2006  \
# 0           M         NaN      A  ...          NaN          NaN          NaN
# 1     CLINTON         NaN      A  ...          NaN            D          NaN
# 2           F         NaN      A  ...          NaN          NaN          NaN
# 3           E         NaN      A  ...          NaN          NaN          NaN
# 4     MICHAEL         NaN      I  ...          NaN          NaN          NaN
#
# ...

# %%
voter_df= vote_df.set_index('voter_id_org')
voter_df.to_csv('precinct.csv')

# %%
precinct_df = vote_df[['voter_id_org', 'Precint']]
precinct_df.head()
# Out:
#    voter_id_org            Precint
# 0       2410948  GARFIELD HTS-04-B
# 1        189273     CLEVELAND-09-H
# 2        504938  INDEPENDENCE-00-E
# 3       2078785  INDEPENDENCE-00-E
# 4       2773489   VALLEY VIEW-00-A

# %%
precinct_df.to_csv('precinct.csv')
