# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
# 1. Create a DataFrame for the primary election data. 
file_to_open = "prim_gen_joined.csv"
primary_elec_df = pd.read_csv(file_to_open, encoding="ISO-8859-1") 
primary_elec_df
# Out:
#         Voter ID           City  Party  Birth Year  Zip Code  \
# 0         704844    SEVEN HILLS  NOPTY        1959     44131
# 1        1658758          PARMA    REP        1968     44130
# 2        2005536  BROADVIEW HTS    REP        1976     44147
# 3        2465762          SOLON  NOPTY        1991     44139
# 4         710633   INDEPENDENCE    REP        1968     44131
# ...          ...            ...    ...         ...       ...
# 873946    689381      PARMA HTS    DEM        1958     44130
# 873947    823935   STRONGSVILLE    REP        1946     44149
# 873948    749942         EUCLID    DEM        1927     44132
# 873949    276903         EUCLID  NOPTY        1944     44132
# 873950   3017222    SEVEN HILLS  NOPTY        1975     44131
#
#        2020 Primary Election 2016 Primary Election 2012 Primary Election  \
# 0                          0                     D                     0
# 1                          0                     R                     R
# 2                          0                     R                     R
# 3                          0                     0                     0
# 4                          0                     R                     R
# ...                      ...                   ...                   ...
# 873946                     D                     D                     0
# 873947                     R                     D                     X
# 873948                     0                     0                     0
# 873949                     0                     0                     0
# 873950                     0                     0                     0
#
#        2008 Primary Election 2020 General Election 2016 General Election  \
# 0                          D                     t                     t
# 1                          D                     t                     t
# 2                          D                     t                     t
# 3                          0                     f                     f
# 4                          0                     t                     t
# ...                      ...                   ...                   ...
# 873946                     D                     t                     t
# 873947                     D                     t                     t
# 873948                     D                     t                     t
# 873949                     0                     f                     f
# 873950                     0                     f                     f
#
#        2012 General Election 2008 General Election
# 0                          t                     t
# 1                          t                     t
# 2                          t                     t
# 3                          t                     f
# 4                          t                     t
# ...                      ...                   ...
# 873946                     t                     t
# 873947                     t                     t
# 873948                     t                     t
# 873949                     t                     t
# 873950                     f                     f
#
# [873951 rows x 13 columns]

# %%
# Establish the spending bins and group names.
age_bins = [0, 1945, 1964, 1980, 1996, 2012]
group_names = ["Silent", "Boomers", "Generation X", "Millennials", "Generation Z"]

# Categorize spending based on the bins.
primary_elec_df["Generational Group"] = pd.cut(primary_elec_df["Birth Year"], age_bins, labels=group_names)

primary_elec_df
# Out:
#         Voter ID           City  Party  Birth Year  Zip Code  \
# 0         704844    SEVEN HILLS  NOPTY        1959     44131
# 1        1658758          PARMA    REP        1968     44130
# 2        2005536  BROADVIEW HTS    REP        1976     44147
# 3        2465762          SOLON  NOPTY        1991     44139
# 4         710633   INDEPENDENCE    REP        1968     44131
# ...          ...            ...    ...         ...       ...
# 873946    689381      PARMA HTS    DEM        1958     44130
# 873947    823935   STRONGSVILLE    REP        1946     44149
# 873948    749942         EUCLID    DEM        1927     44132
# 873949    276903         EUCLID  NOPTY        1944     44132
# 873950   3017222    SEVEN HILLS  NOPTY        1975     44131
#
#        2020 Primary Election 2016 Primary Election 2012 Primary Election  \
# 0                          0                     D                     0
# 1                          0                     R                     R
# 2                          0                     R                     R
# 3                          0                     0                     0
# 4                          0                     R                     R
# ...                      ...                   ...                   ...
# 873946                     D                     D                     0
# 873947                     R                     D                     X
# 873948                     0                     0                     0
# 873949                     0                     0                     0
# 873950                     0                     0                     0
#
#        2008 Primary Election 2020 General Election 2016 General Election  \
# 0                          D                     t                     t
# 1                          D                     t                     t
# 2                          D                     t                     t
# 3                          0                     f                     f
# 4                          0                     t                     t
# ...                      ...                   ...                   ...
# 873946                     D                     t                     t
# 873947                     D                     t                     t
# 873948                     D                     t                     t
# 873949                     0                     f                     f
# 873950                     0                     f                     f
#
#        2012 General Election 2008 General Election Generational Group
# 0                          t                     t            Boomers
# 1                          t                     t       Generation X
# 2                          t                     t       Generation X
# 3                          t                     f        Millennials
# 4                          t                     t       Generation X
# ...                      ...                   ...                ...
# 873946                     t                     t            Boomers
# 873947                     t                     t            Boomers
# 873948                     t                     t             Silent
# 873949                     t                     t             Silent
# 873950                     f                     f       Generation X
#
# [873951 rows x 14 columns]

# %%
primary_elec_df.loc[(primary_elec_df[""])]
