# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
# 1. Create a DataFrame for the Generational Groups data. 
file_to_open = (r"C:\Users\emadn\Class\GoVote\Generational_Groups_df.csv")
Generational_groups_df = pd.read_csv(file_to_open, encoding="ISO-8859-1") 
Generational_groups_df
# Out:
#         Unnamed: 0  Voter ID           City  Party  Birth Year  Zip Code  \
# 0                0    704844    SEVEN HILLS  NOPTY        1959     44131
# 1                1   1658758          PARMA    REP        1968     44130
# 2                2   2005536  BROADVIEW HTS    REP        1976     44147
# 3                3   2465762          SOLON  NOPTY        1991     44139
# 4                4    710633   INDEPENDENCE    REP        1968     44131
# ...            ...       ...            ...    ...         ...       ...
# 870070      870070     89841    BRECKSVILLE    REP        1944     44141
# 870071      870071    689381      PARMA HTS    DEM        1958     44130
# 870072      870072    823935   STRONGSVILLE    REP        1946     44149
# 870073      870073    276903         EUCLID  NOPTY        1944     44132
# 870074      870074   3017222    SEVEN HILLS  NOPTY        1975     44131
#
#        2020 Primary Election 2016 Primary Election 2012 Primary Election  \
# ...

# %%
Generational_groups_df.columns
# Out:
# Index(['Unnamed: 0', 'Voter ID', 'City', 'Party', 'Birth Year', 'Zip Code',
#        '2020 Primary Election', '2016 Primary Election',
#        '2012 Primary Election', '2008 Primary Election',
#        '2020 General Election', '2016 General Election',
#        '2012 General Election', '2008 General Election', 'Generational_Group'],
#       dtype='object')

# %%
Generational_groups_df = Generational_groups_df.drop(Generational_groups_df.columns[[0, 1, 2, 3, 4, 5]], axis=1)
Generational_groups_df.head()
# Out:
#   2020 Primary Election 2016 Primary Election 2012 Primary Election  \
# 0                     0                     D                     0
# 1                     0                     R                     R
# 2                     0                     R                     R
# 3                     0                     0                     0
# 4                     0                     R                     R
#
#   2008 Primary Election 2020 General Election 2016 General Election  \
# 0                     D                     t                     t
# 1                     D                     t                     t
# 2                     D                     t                     t
# 3                     0                     f                     f
# 4                     0                     t                     t
#
#   2012 General Election 2008 General Election Generational_Group
# 0                     t                     t            Boomers
# ...

# %%
#Replace True and False Values with 0 and 1
Generational_groups_df.replace(('D', 'R', 'N', 'L', 'G', 'X', 't', 'f'), (1, 1, 1, 1, 1, 1, 1, 0), inplace=True)
Generational_groups_df
# Out:
#        2020 Primary Election 2016 Primary Election 2012 Primary Election  \
# 0                          0                     1                     0
# 1                          0                     1                     1
# 2                          0                     1                     1
# 3                          0                     0                     0
# 4                          0                     1                     1
# ...                      ...                   ...                   ...
# 870070                     0                     1                     1
# 870071                     1                     1                     0
# 870072                     1                     1                     1
# 870073                     0                     0                     0
# 870074                     0                     0                     0
#
#        2008 Primary Election  2020 General Election  2016 General Election  \
# ...

# %%
Generational_groups_df.to_csv('Generational_GroupS_clean.csv')

# %%
Generational_groups_df['Generational_Group'].value_counts()
# Out:
# Millennials     257062
# Boomers         255137
# Generation X    206810
# Generation Z     79480
# Silent           71586
# Name: Generational_Group, dtype: int64

# %%
Silent_df= Generational_groups_df.loc[Generational_groups_df['Generational_Group'] == "Silent"]
Silent_df
# Out:
#        2020 Primary Election 2016 Primary Election 2012 Primary Election  \
# 32                         0                     0                     0
# 62                         0                     1                     0
# 63                         1                     1                     1
# 125                        0                     0                     0
# 128                        1                     1                     0
# ...                      ...                   ...                   ...
# 870043                     1                     0                     0
# 870059                     0                     0                     0
# 870065                     1                     1                     1
# 870070                     0                     1                     1
# 870073                     0                     0                     0
#
#        2008 Primary Election  2020 General Election  2016 General Election  \
# ...

# %%
Boomers_df= Generational_groups_df.loc[Generational_groups_df['Generational_Group'] == "Boomers"]
Boomers_df
# Out:
#        2020 Primary Election 2016 Primary Election 2012 Primary Election  \
# 0                          0                     1                     0
# 6                          0                     1                     0
# 8                          0                     0                     0
# 10                         1                     1                     0
# 13                         0                     0                     0
# ...                      ...                   ...                   ...
# 870063                     1                     1                     1
# 870066                     0                     0                     0
# 870067                     1                     1                     0
# 870071                     1                     1                     0
# 870072                     1                     1                     1
#
#        2008 Primary Election  2020 General Election  2016 General Election  \
# ...

# %%
Millennials_df= Generational_groups_df.loc[Generational_groups_df['Generational_Group'] == "Millennials"]
Millennials_df
# Out:
#        2020 Primary Election 2016 Primary Election 2012 Primary Election  \
# 3                          0                     0                     0
# 5                          0                     0                     0
# 12                         0                     1                     0
# 16                         0                     1                     0
# 19                         0                     1                     0
# ...                      ...                   ...                   ...
# 870046                     0                     0                     0
# 870048                     0                     0                     0
# 870055                     0                     0                     0
# 870057                     0                     0                     0
# 870061                     0                     1                     1
#
#        2008 Primary Election  2020 General Election  2016 General Election  \
# ...

# %%
GenX_df= Generational_groups_df.loc[Generational_groups_df['Generational_Group'] == "Generation X"]
GenX_df
# Out:
#        2020 Primary Election 2016 Primary Election 2012 Primary Election  \
# 1                          0                     1                     1
# 2                          0                     1                     1
# 4                          0                     1                     1
# 9                          0                     0                     0
# 14                         0                     0                     0
# ...                      ...                   ...                   ...
# 870060                     0                     0                     0
# 870064                     0                     0                     0
# 870068                     0                     1                     1
# 870069                     0                     0                     0
# 870074                     0                     0                     0
#
#        2008 Primary Election  2020 General Election  2016 General Election  \
# ...

# %%
GenZ_df= Generational_groups_df.loc[Generational_groups_df['Generational_Group'] == "Generation Z"]
GenZ_df
# Out:
#        2020 Primary Election 2016 Primary Election 2012 Primary Election  \
# 7                          0                     0                     0
# 11                         0                     0                     0
# 15                         0                     0                     0
# 23                         1                     1                     0
# 24                         0                     0                     0
# ...                      ...                   ...                   ...
# 870025                     0                     0                     0
# 870027                     1                     0                     0
# 870034                     1                     0                     0
# 870052                     0                     0                     0
# 870056                     0                     0                     0
#
#        2008 Primary Election  2020 General Election  2016 General Election  \
# ...

# %%
del Silent_df['Generational_Group']
del Boomers_df['Generational_Group']
del Millennials_df['Generational_Group']
del GenX_df['Generational_Group']
del GenZ_df['Generational_Group']

# %%
Silent_df
# Out:
#        2020 Primary Election 2016 Primary Election 2012 Primary Election  \
# 32                         0                     0                     0
# 62                         0                     1                     0
# 63                         1                     1                     1
# 125                        0                     0                     0
# 128                        1                     1                     0
# ...                      ...                   ...                   ...
# 870043                     1                     0                     0
# 870059                     0                     0                     0
# 870065                     1                     1                     1
# 870070                     0                     1                     1
# 870073                     0                     0                     0
#
#        2008 Primary Election  2020 General Election  2016 General Election  \
# ...

# %%
Boomers_df
# Out:
#        2020 Primary Election 2016 Primary Election 2012 Primary Election  \
# 0                          0                     1                     0
# 6                          0                     1                     0
# 8                          0                     0                     0
# 10                         1                     1                     0
# 13                         0                     0                     0
# ...                      ...                   ...                   ...
# 870063                     1                     1                     1
# 870066                     0                     0                     0
# 870067                     1                     1                     0
# 870071                     1                     1                     0
# 870072                     1                     1                     1
#
#        2008 Primary Election  2020 General Election  2016 General Election  \
# ...

# %%
Millennials_df
# Out:
#        2020 Primary Election 2016 Primary Election 2012 Primary Election  \
# 3                          0                     0                     0
# 5                          0                     0                     0
# 12                         0                     1                     0
# 16                         0                     1                     0
# 19                         0                     1                     0
# ...                      ...                   ...                   ...
# 870046                     0                     0                     0
# 870048                     0                     0                     0
# 870055                     0                     0                     0
# 870057                     0                     0                     0
# 870061                     0                     1                     1
#
#        2008 Primary Election  2020 General Election  2016 General Election  \
# ...

# %%
GenX_df
# Out:
#        2020 Primary Election 2016 Primary Election 2012 Primary Election  \
# 1                          0                     1                     1
# 2                          0                     1                     1
# 4                          0                     1                     1
# 9                          0                     0                     0
# 14                         0                     0                     0
# ...                      ...                   ...                   ...
# 870060                     0                     0                     0
# 870064                     0                     0                     0
# 870068                     0                     1                     1
# 870069                     0                     0                     0
# 870074                     0                     0                     0
#
#        2008 Primary Election  2020 General Election  2016 General Election  \
# ...

# %%
GenZ_df
# Out:
#        2020 Primary Election 2016 Primary Election 2012 Primary Election  \
# 7                          0                     0                     0
# 11                         0                     0                     0
# 15                         0                     0                     0
# 23                         1                     1                     0
# 24                         0                     0                     0
# ...                      ...                   ...                   ...
# 870025                     0                     0                     0
# 870027                     1                     0                     0
# 870034                     1                     0                     0
# 870052                     0                     0                     0
# 870056                     0                     0                     0
#
#        2008 Primary Election  2020 General Election  2016 General Election  \
# ...

# %%
Silent_df.to_csv('Silent_Voters.csv')
Boomers_df.to_csv('Boomers_Voters.csv')
Millennials_df.to_csv('Millennials_Voters.csv')
GenX_df.to_csv('GenX_Voters.csv')
GenZ_df.to_csv('GenZ_Voters.csv')
