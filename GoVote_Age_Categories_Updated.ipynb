# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
# 1. Create a DataFrame for the primary election data. 
file_to_open = (r"C:\Users\emadn\Class\GoVote\Resources\go_vote.csv")
primary_elec_df = pd.read_csv(file_to_open, encoding="ISO-8859-1") 
primary_elec_df
# Out:
#         Voter ID           City  Party  Birth Year  Zip Code  \
# 0         704844    SEVEN HILLS  NOPTY        1959     44131
# 1        1658758          PARMA    REP        1968     44130
# 2        2005536  BROADVIEW HTS    REP        1976     44147
# 3        2465762          SOLON  NOPTY        1991     44139
# 4         710633   INDEPENDENCE    REP        1968     44131
# ...          ...            ...    ...         ...       ...
# 870070     89841    BRECKSVILLE    REP        1944     44141
# 870071    689381      PARMA HTS    DEM        1958     44130
# 870072    823935   STRONGSVILLE    REP        1946     44149
# 870073    276903         EUCLID  NOPTY        1944     44132
# 870074   3017222    SEVEN HILLS  NOPTY        1975     44131
#
#        2020 Primary Election 2016 Primary Election 2012 Primary Election  \
# 0                          0                     D                     0
# 1                          0                     R                     R
# ...

# %%
# Establish the spending bins and group names.
age_bins = [0, 1945, 1964, 1980, 1996, 2012]
group_names = ["Silent", "Boomers", "Generation X", "Millennials", "Generation Z"]

# Categorize spending based on the bins.
primary_elec_df["Generational_Group"] = pd.cut(primary_elec_df["Birth Year"], age_bins, labels=group_names)

primary_elec_df
# Out:
#         Voter ID           City  Party  Birth Year  Zip Code  \
# 0         704844    SEVEN HILLS  NOPTY        1959     44131
# 1        1658758          PARMA    REP        1968     44130
# 2        2005536  BROADVIEW HTS    REP        1976     44147
# 3        2465762          SOLON  NOPTY        1991     44139
# 4         710633   INDEPENDENCE    REP        1968     44131
# ...          ...            ...    ...         ...       ...
# 870070     89841    BRECKSVILLE    REP        1944     44141
# 870071    689381      PARMA HTS    DEM        1958     44130
# 870072    823935   STRONGSVILLE    REP        1946     44149
# 870073    276903         EUCLID  NOPTY        1944     44132
# 870074   3017222    SEVEN HILLS  NOPTY        1975     44131
#
#        2020 Primary Election 2016 Primary Election 2012 Primary Election  \
# 0                          0                     D                     0
# 1                          0                     R                     R
# ...

# %%
#Generational Groups
primary_elec_df.to_csv('Generational_Groups_df.csv')

# %%
#ALL VOTERS ELIGIBLE FOR 2016
voters2016_df= primary_elec_df.loc[primary_elec_df["Birth Year"] <=1998]
voters2016_df.shape
# Out:
# (820467, 14)

# %%
voters2016_df.to_csv('voters2016_df.csv')

# %%
#ALL VOTERS ELIGIBLE FOR 2012
voters2012_df= primary_elec_df.loc[primary_elec_df["Birth Year"] <=1994]
voters2012_df.shape
# Out:
# (758747, 14)

# %%
voters2012_df.to_csv('voters2012_df.csv')

# %%
#ALL VOTERS ELIGIBLE FOR 2008
voters2008_df= primary_elec_df.loc[primary_elec_df["Birth Year"] <=1990]
voters2008_df.shape
# Out:
# (688423, 14)

# %%
voters2008_df.to_csv('voters2008_df.csv')
